# %% [markdown]
# <a href="https://colab.research.google.com/github/rootofdata/kostat_AI_contest/blob/main/%5BFinal%5Dsubmission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pylab as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
submission= pd.read_csv('/content/drive/MyDrive/통계청_AI경진대회/모델 개발용 자료/모델 개발용 자료.csv',header=1)

# %%
import re
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타냅니다.
    result = hangul.sub('', text)
    return result

# %%
# !pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 448 kB 45.9 MB/s
# ...

# %%
col = ['text_obj','text_mthd','text_deal']
NLP = submission[col].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
df = submission[['AI_id','digit_3']].copy()
df['NLP'] = NLP

# %%
df
# Out:
#            AI_id  digit_3                         NLP
# 0      id_000001      NaN       치킨전문점에서 고객의주문에의해 치킨판매
# 1      id_000002      NaN       산업공구 다른 소매업자에게 철물 수공구
# 2      id_000003      NaN         절에서 신도을 대상으로 불교단체운영
# 3      id_000004      NaN           영업장에서 고객요구로 자동차튜닝
# 4      id_000005      NaN  실내포장마차에서 접객시설을 갖추고 소주,맥주제공
# ...          ...      ...                         ...
# 99995  id_099996      NaN          사업장에서 일반인대상으로 버섯농장
# 99996  id_099997      NaN            한의원에서 외래환자위주고 치료
# 99997  id_099998      NaN           일반점포에서 소비자에게 그림판매
# 99998  id_099999      NaN     사업장에서 일반인.학생대상으로 학습공간제공
# 99999  id_100000      NaN           사업장에서 대리현대아파트를 관리
#
# [100000 rows x 3 columns]

# %%
for i in NLP:
  text_cleaning(i)

# %%
from konlpy.tag import Okt
okt = Okt()
submission_okt = []
for i in range(len(NLP)):
  submission_okt.append(okt.nouns(NLP[i]))

# %%
submission=submission_okt.copy()

# %% [markdown]
# # Split 8->4

# %%
count={}
for j in range(len(submission)):
  for i in submission[j]:
      try: count[i] += 1
      except: count[i]=1
bigword8 = {key: value for key, value in count.items() if len(key)==8 and value <50}
bw8= list(bigword8)
bw8_copy=bw8.copy()
def split8(data_name,i):
  data_name =bw8.copy()
  for k in range(len(bw8)):
    d=[]
    d.append(data_name[k][0:i])
    d.append(data_name[k][i:8])
    data_name[k]=d
  return data_name
b8_2=[]
b8_4=[]
b8_6=[]
b8_2=split8(b8_2,2)
b8_4=split8(b8_4,4)
b8_6=split8(b8_6,6)
for i in range(len(bw8_copy)):
  for j in range(len(submission)):
    for item in submission[j]:
      if item ==bw8_copy[i]:
         submission[j].remove(bw8_copy[i])
         submission[j].append(b8_2[i][0])
         submission[j].append(b8_2[i][1])
         submission[j].append(b8_4[i][0])
         submission[j].append(b8_4[i][1])    
         submission[j].append(b8_6[i][0])
         submission[j].append(b8_6[i][1])

# %%
count={}
for j in range(len(submission)):
  for i in submission[j]:
      try: count[i] += 1
      except: count[i]=1
bigword7 = {key: value for key, value in count.items() if len(key)==7 and value <50}
bw7= list(bigword7)
bw7_copy=bw7.copy()
def split7(data_name,i):
  data_name =bw7.copy()
  for k in range(len(bw7)):
    d=[]
    d.append(data_name[k][0:i])
    d.append(data_name[k][i:7])
    data_name[k]=d
  return data_name
b7_2=[]
b7_4=[]
b7_2=split7(b7_2,2)
b7_4=split7(b7_4,4)
for i in range(len(bw7_copy)):
  for j in range(len(submission)):
    for item in submission[j]:
      if item ==bw7_copy[i]:
         submission[j].remove(bw7_copy[i])
         submission[j].append(b7_2[i][0])
         submission[j].append(b7_2[i][1])
         submission[j].append(b7_4[i][0])
         submission[j].append(b7_4[i][1])

# %%
count={}
for j in range(len(submission)):
  for i in submission[j]:
      try: count[i] += 1
      except: count[i]=1
bigword6 = {key: value for key, value in count.items() if len(key)==6 and value <50}
bw6= list(bigword6)
bw6_copy=bw6.copy()
def split6(data_name,i):
  data_name =bw6.copy()
  for k in range(len(bw6)):
    d=[]
    d.append(data_name[k][0:i])
    d.append(data_name[k][i:6])
    data_name[k]=d
  return data_name
b6_2=[]
b6_3=[]
b6_4=[]
b6_2=split6(b6_2,2)
b6_3=split6(b6_3,3)
b6_4=split6(b6_4,4)
for i in range(len(bw6_copy)):
  for j in range(len(submission)):
    for item in submission[j]:
      if item ==bw6_copy[i]:
         submission[j].remove(bw6_copy[i])
         submission[j].append(b6_2[i][0])
         submission[j].append(b6_2[i][1])
         submission[j].append(b6_3[i][0])
         submission[j].append(b6_3[i][1])
         submission[j].append(b6_4[i][0])
         submission[j].append(b6_4[i][1])

# %%
count={}
for j in range(len(submission)):
  for i in submission[j]:
      try: count[i] += 1
      except: count[i]=1
bigword5 = {key: value for key, value in count.items() if len(key)==5 and value <50}
bw5= list(bigword5)
bw5_copy=bw5.copy()
def split5(data_name,i):
  data_name =bw5.copy()
  for k in range(len(bw5)):
    d=[]
    d.append(data_name[k][0:i])
    d.append(data_name[k][i:5])
    data_name[k]=d
  return data_name
b5_2=[]
b5_3=[]
b5_2=split5(b5_2,2)
b5_3=split5(b5_3,3)
for i in range(len(bw5_copy)):
  for j in range(len(submission)):
    for item in submission[j]:
      if item ==bw5_copy[i]:
         submission[j].remove(bw5_copy[i])
         submission[j].append(b5_2[i][0])
         submission[j].append(b5_2[i][1])
         submission[j].append(b5_3[i][0])
         submission[j].append(b5_3[i][1])

# %%
count={}
for j in range(len(submission)):
  for i in submission[j]:
      try: count[i] += 1
      except: count[i]=1
bigword4 = {key: value for key, value in count.items() if len(key)==4 and value <50}
bw4= list(bigword4)
bw4_copy=bw4.copy()
def split4(data_name,i):
  data_name =bw4.copy()
  for k in range(len(bw4)):
    d=[]
    d.append(data_name[k][0:i])
    d.append(data_name[k][i:4])
    data_name[k]=d
  return data_name
b4_1=[]
b4_2=[]
b4_3=[]
b4_1=split4(b4_1,1)
b4_2=split4(b4_2,2)
b4_3=split4(b4_3,3)
for i in range(len(bw4_copy)):
  for j in range(len(submission)):
    for item in submission[j]:
      if item ==bw4_copy[i]:
        submission[j].append(b4_1[i][0])
        submission[j].append(b4_1[i][1])
        submission[j].append(b4_2[i][0])
        submission[j].append(b4_2[i][1])
        submission[j].append(b4_3[i][0])
        submission[j].append(b4_3[i][1])  
      else: continue

# %% [markdown]
# # 불용어 처리

# %%
import pandas as pd
stop_words = pd.read_csv('/content/drive/MyDrive/통계청_AI경진대회/한국어불용어100.txt',header=None, encoding ='utf-8',sep='\t')
stop_words = stop_words[0]

# %%
for i in range(len(stop_words)):
  for j in range(len(submission)):
    for item in submission[j]:
      if item ==stop_words[i]:
          submission[j].remove(stop_words[i])

# %%
search=['매장','대상','서비스','고객','시설','접객','사업','일반인','판매','요청','제공','중개','영업','일반','제조','및','등','업','용','해','류','위','도','집','타','통해','입','물','전','기타',
        '내','미만','상대로','스','로부터','위해','실','재','초','비','품','기','사','임','절','학','관','인','통해','캐','후','제','함','내부','즙','를','유','리','의','트','산','골','손','틀','접',
        '영','활','무','폐','드','다른','케','목','난','수','상','고', '사업장', '사무실', '가게', '매장', '영업장', '현장', '시설', '개인','계약', '의뢰', '수련장', '가공', '관리', '위주', '산업', '개별','운영',
        '활동', '요구', '업체', '음', '제작', '용품', '점', '가지','류', '각종', '의거', '대리', '체결', '설치', '방', '재료', '알선', '센터', '통해','전문', '수집', '기기', '업무', '부분', '실내', '특정', '서비스업',
        '단체', '구입', '온라인','소비자','사용자','사무소'] #불용어 추가하면 됨.
for i in range(len(search)):
  for j in range(len(submission)):
    for item in submission[j]:
      if item ==search[i]:
          submission[j].remove(search[i])

# %%
remove_set =['카','철','쌀','떡','술','빵','집','차','닭','원','꽃','옷','펌','톱','쇠','소','콩','훍','약','은','중','즙','땅','풀','밥','면','회','찜','배','산','벼','금','숯']
bw = [i for i in submission if i not in remove_set]

# %%
for i in range(len(bw)):
  for j in range(len(submission)):
    for item in submission[j]:
      if item ==bw[i]:
          submission[j].remove(bw[i])

# %%
submission
# Out:
# [['치킨', '전문점', '주문', '치킨'],
#  ['공구', '소매업자', '철물', '공구'],
#  ['불교'],
#  ['자동', '차튜닝', '자동차', '튜닝'],
#  ['포장마차', '소주', '맥주', '포', '장마차', '포장', '마차', '포장마', '차'],
#  ['철', '아크릴', '포', '맥스', '스크린', '인쇄', '명판'],
#  ['음식점', '조개', '구이'],
#  ['스테인레스', '프레', '여제', '주방용품'],
#  ['수리', '수리', '수입', '차'],
#  ['약품', '화공', '미싱', '완성', '수선'],
#  ['밀가루', '쇼트닝', '반죽'],
#  ['이발소', '두발', '손질'],
#  ['목재', '무대', '장치'],
#  ['의원', '소아', '청소년', '진료'],
#  ['조성', '시', '측량', '토목', '설계'],
#  ['태국', '전통', '마사지', '마사지'],
#  ['관련', '선박', '엔진', '부품'],
#  ['상가', '주문', '반찬', '도시락'],
#  ['구류', '사무', '소매'],
#  ['엔지니어링', '건축', '관련', '도면', '설계'],
#  ['스테인레스', '메탈', '도금', '샤워'],
#  ['매니큐어', '용기', '매', '니큐어', '매니', '큐어', '매니큐', '어'],
#  ['보호', '요양보호사', '파견'],
#  ['점포', '세탁'],
#  ['우드', '카운티', '나무', '용해', '가구', '주문'],
#  ['컴퓨터', '핸드폰', '수리'],
#  ['구두', '소매'],
#  [],
#  ['부동산', '수수료', '부동산', '거래'],
#  ['인터넷', '인터넷'],
#  ['어린이', '방문', '교육학', '습지'],
#  ['선', '별장', '농산물', '도매'],
#  ['음식점', '보쌈', '음식'],
# ...

# %%
import pickle
with open('/content/drive/MyDrive/통계청_AI경진대회/final/data/submission','wb') as f:
    pickle.dump(submission,f)
